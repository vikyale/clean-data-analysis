# %%
import pandas as pd
import numpy as np

# %%
##Cargamos la base
df = pd.read_csv('tratamiento.csv', sep=';')

# %%
##Consultamos
df
# Out:
#     Nombre Sexo empresa1  empresa2
# 0     Juan    M        -         4
# 1     Luis    M       23         5
# 2    Maria    F       12        66
# 3    Kenny    F       34        54
# 4     John    M       10        32
# 5   Daniel    M       15        23
# 6    Carla    F       23        12
# 7  Monnica    F        -        43
# 8  Monnica    F        -        43

# %%
##Consultamos los tipos de datos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
# Nombre      9 non-null object
# Sexo        9 non-null object
# empresa1    9 non-null object
# empresa2    9 non-null int64
# dtypes: int64(1), object(3)
# memory usage: 220.0+ bytes

# %%
##Vemos que el tipo de dato en Sexo es objeto, debemos cambiarlo a tipo categorico
##Es importante porque hace el dataframe más pequeño en la memoria
##Permite que sea analizado por otras bibliotecas(librerias) de python.

df['Sexo']=df['Sexo'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
# Nombre      9 non-null object
# Sexo        9 non-null category
# empresa1    9 non-null object
# empresa2    9 non-null int64
# dtypes: category(1), int64(1), object(2)
# memory usage: 249.0+ bytes

# %%
##Vemos que el tipo de dato en empres1 es objeto(String), 
##lo cambiaremos a numerico
df['empresa1'] = pd.to_numeric(df['empresa1'],errors='coerce')

# %%
df
# Out:
#     Nombre Sexo  empresa1  empresa2
# 0     Juan    M       NaN         4
# 1     Luis    M      23.0         5
# 2    Maria    F      12.0        66
# 3    Kenny    F      34.0        54
# 4     John    M      10.0        32
# 5   Daniel    M      15.0        23
# 6    Carla    F      23.0        12
# 7  Monnica    F       NaN        43
# 8  Monnica    F       NaN        43

# %%
print(df)
# Out:
#     Nombre Sexo  empresa1  empresa2
# 0     Juan    M       NaN         4
# 1     Luis    M      23.0         5
# 2    Maria    F      12.0        66
# 3    Kenny    F      34.0        54
# 4     John    M      10.0        32
# 5   Daniel    M      15.0        23
# 6    Carla    F      23.0        12
# 7  Monnica    F       NaN        43
# 8  Monnica    F       NaN        43

# %%
##Borrar duplicados
##Nos damos cuenta que la ultima fila esta duplicada
df_dup=df.drop_duplicates()

# %%
df_dup
# Out:
#     Nombre Sexo  empresa1  empresa2
# 0     Juan    M       NaN         4
# 1     Luis    M      23.0         5
# 2    Maria    F      12.0        66
# 3    Kenny    F      34.0        54
# 4     John    M      10.0        32
# 5   Daniel    M      15.0        23
# 6    Carla    F      23.0        12
# 7  Monnica    F       NaN        43

# %%
##Missing data

# %%
propinas_nan = pd.read_csv('propinas.csv', sep=',')

# %%
propinas_nan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304 entries, 0 to 303
# Data columns (total 7 columns):
# total_cuenta    293 non-null float64
# propina         299 non-null float64
# sex             303 non-null object
# fumador         302 non-null object
# dia             303 non-null object
# tiempo          300 non-null object
# cantidad        300 non-null object
# dtypes: float64(2), object(5)
# memory usage: 10.7+ KB

# %%
propinas_drop.head(100)
# Out:
#     total_cuenta  propina        sex fumador        dia  tiempo cantidad
# 0          16.99     1.01   Femenino      No     Sabado    Cena        2
# 3         23.68      NaN  Masculino      No  Sabado   Cena        2
# 4         24.59     3.61    missing      No  Sabado   Cena        4
# 5         25.29     4.71  Masculino      No  Sabado   Cena        4
# 6          8.77     2.00  Masculino      No  Sabado   Cena        2
# 7         26.88     3.12  Masculino      No  Sabado   Cena        4
# 8         15.04     1.96  Masculino      No  Sabado   Cena        2
# 9         14.78     3.23  Masculino      No  Sabado   Cena        2

# %%
##Llenando valores vacios con un test stadistico
#Tener cuidado de usar un test estadistico para llenar
#El valor llenado debe tener sentido
#La mediana es uno de los mejores estadisticas in la presencia de outliers.

# %%
mean_value=propinas_nan['propina'].mean()

# %%
print(mean_value)
# Out:
# 3.2143478260869567

# %%
propinas_nan['propina'] = propinas_nan['propina'].fillna(mean_value)

# %%
propinas_nan.head(10)
# Out:
#    total_cuenta   propina        sex fumador     dia tiempo cantidad
# 0         16.99  1.010000   Femenino      No  Sabado   Cena        2
# 1          0.00  1.660000  Masculino      No  Sabado   Cena        3
# 2         21.01  3.500000  Masculino      No  Sabado   Cena        3
# 3         23.68  3.214348  Masculino      No  Sabado   Cena        2
# 4         24.59  3.610000    missing      No  Sabado   Cena        4
# 5         25.29  4.710000  Masculino      No  Sabado   Cena        4
# 6          8.77  2.000000  Masculino      No  Sabado   Cena        2
# 7         26.88  3.120000  Masculino      No  Sabado   Cena        4
# 8         15.04  1.960000  Masculino      No  Sabado   Cena        2
# 9         14.78  3.230000  Masculino      No  Sabado   Cena        2

# %%
##Comprobacion por codigo vs visual checking
#Podremos escribir una sentencia assert para verificar si tenemos NaNs o esperamos missings values
# Podemos detectar errores y warnings tempranos
#Nos da confianza que nuestro codigo esta corriento correctamente

# %%
assert 1==1

# %%
assert 1==2
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-54-730332727407> in <module>
# ----> 1 assert 1==2
#
# AssertionError:

# %%
propinas= pd.read_csv('propinas.csv', sep=',')

# %%
assert propinas.propina.notnull().all()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-58-4a75014d6e15> in <module>
# ----> 1 assert propinas.propina.notnull().all()
#
# AssertionError:

# %%
propinas_0 = propinas.fillna(value=0)

# %%
##Asigna a todos los valores NaN
assert propinas_0.propina.notnull().all()

# %%
propinas_0.head(10)
# Out:
#    total_cuenta  propina        sex fumador     dia tiempo cantidad
# 0         16.99     1.01   Femenino      No  Sabado   Cena        2
# 1          0.00     1.66  Masculino      No  Sabado   Cena        3
# 2         21.01     3.50  Masculino      No  Sabado   Cena        3
# 3         23.68     0.00  Masculino      No  Sabado   Cena        2
# 4         24.59     3.61          0      No  Sabado   Cena        4
# 5         25.29     4.71  Masculino      No  Sabado   Cena        4
# 6          8.77     2.00  Masculino      No  Sabado   Cena        2
# 7         26.88     3.12  Masculino      No  Sabado   Cena        4
# 8         15.04     1.96  Masculino      No  Sabado   Cena        2
# 9         14.78     3.23  Masculino      No  Sabado   Cena        2
