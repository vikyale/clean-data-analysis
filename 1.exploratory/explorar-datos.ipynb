# %%
import pandas as pd

# %%
df = pd.read_csv('tasa_natalidad.csv',sep=',')

# %%
df
# Out:
#                                   pais  continente  alfabetizacion femenina  \
# 0                                 Chine        ASI                     90.5
# 1                                  Inde        ASI                     50.8
# 2                                   USA        NAM                     99.0
# 3                             Indonésie        ASI                     88.8
# 4                                Brésil        LAT                     90.2
# 5                              Pakistan        ASI                     40.0
# 6                            Bangladesh        ASI                     49.8
# 7                               Nigéria         AF                     48.8
# 8                  Fédération de Russie        EUR                     99.4
# 9                                 Japan        ASI                     99.0
# 10                              Mexique        LAT                     91.5
# 11                          Philippines        ASI                     93.9
# 12                             Viet Nam        ASI                     90.2
# 13                              Germany        EUR                     99.0
# 14                               Egypte         AF                     57.8
# 15                             Ethiopie         AF                     22.8
# 16                              Turquie        ASI                     81.3
# 17        Iran, République islamique d'        ASI                     77.2
# 18                            Thaïlande        ASI                     91.5
# 19           Rép. Démocratique du Congo         AF                     56.1
# 20                               France        EUR                     99.0
# 21                                   UK        EUR                     99.0
# 22                               Italie        EUR                     98.5
# 23                              Myanmar        ASI                     89.2
# 24                       Afrique du Sud         AF                     88.1
# 25                          South Korea        ASI                     96.6
# 26                              Ukraine        EUR                     99.6
# 27                              Espagne        EUR                     96.9
# 28                             Colombie        LAT                     93.4
# 29          République-Unie de Tanzanie         AF                     66.3
# ..                                  ...        ...                      ...
# 138                               Gabon         AF                     83.2
# 139                             Estonie        EUR                     99.8
# 140                   Trinité-et-Tobago        LAT                     98.2
# 141                               Qatar        ASI                     90.4
# 142                             Maurice         AF                     84.8
# 143                           Swaziland         AF                     85.6
# 144                              Chypre        EUR                     96.7
# 145                             Bahreïn        ASI                     89.4
# 146                             Bhoutan        ASI                     38.7
# 147                  Guinée équatoriale         AF                     89.1
# 148                             Comores         AF                     67.8
# 149                        Macao, Chine        ASI                     90.7
# 150                            Suriname        LAT                     88.4
# 151                            Cap-Vert         AF                     79.3
# 152                               Malte        EUR                     93.5
# 153                   Brunéi Darussalam        ASI                     93.3
# 154                             Bahamas        LAT                     96.5
# 155                             Iceland        EUR                     99.0
# 156                            Maldives        ASI                     98.4
# 157                             Vanuatu        OCE                     79.5
# 158                               Samoa        OCE                     98.5
# 159                Sao Tomé-et-Principe         AF                     83.3
# 160                               Aruba        LAT                     98.0
# 161                               Tonga        ASI                     99.1
# 162                  Antigua-et-Barbuda        NaN                     99.4
# 163              Antilles néerlandaises        NaN                     96.3
# 164                       Iles Caïmanes        NaN                     99.0
# 165                          Seychelles        NaN                     92.3
# 166  Territoires autonomes palestiniens        NaN                     90.9
# 167                               WORLD      WORLD                     77.0
#
#     fertilidad      poblacion
# 0        1.769  1,324,655,000
# 1        2.682  1,139,964,932
# 2        2.077    304,060,000
# 3        2.132    227,345,082
# 4        1.827    191,971,506
# 5        3.872    166,111,487
# 6        2.288    160,000,128
# 7        5.173    151,212,254
# 8        1.393    141,950,000
# 9        1.262    127,704,000
# 10       2.156    106,350,434
# 11       3.026     90,348,437
# 12       2.033     86,210,781
# 13       1.324     82,110,097
# 14       2.816     81,527,172
# 15       5.211     80,713,434
# 16         2.1     73,914,260
# 17       1.781     71,956,322
# 18       1.822     67,386,383
# 19       5.908     64,256,635
# 20       1.881     62,277,432
# 21       1.852     61,414,062
# 22        1.39     59,832,179
# 23       2.281     49,563,019
# 24       2.505     48,687,000
# 25       1.224     48,607,000
# 26       1.361     46,258,200
# 27       1.468     45,555,716
# 28       2.404     45,012,096
# 29        5.52     42,483,923
# ..         ...            ...
# 138       3.24      1,448,159
# 139      1.693      1,340,675
# 140      1.647      1,333,388
# 141       2.36      1,280,862
# 142      1.792      1,268,854
# 143       3.45      1,167,834
# 144      1.516        862,434
# 145      2.233        775,585
# 146      2.563        686,789
# 147      5.283        659,197
# 148      3.885        643,571
# 149      0.966        526,178
# 150      2.373        515,124
# 151      2.663        498,672
# 152      1.251        411,950
# 153      2.052        392,280
# 154      3.371        337,668
# 155      2.093        317,414
# 156          2        305,027
# 157      3.883        233,866
# 158      3.852        178,869
# 159      3.718        160,174
# 160      1.732        105,455
# 161      3.928        103,566
# 162    missing            NaN
# 163    missing            NaN
# 164    missing            NaN
# 165    missing            NaN
# 166    missing            NaN
# 167        NaN            NaN
#
# [168 rows x 5 columns]

# %%
df.head(10)
# Out:
#                   pais  continente  alfabetizacion femenina fertilidad  \
# 0                 Chine        ASI                     90.5      1.769
# 1                  Inde        ASI                     50.8      2.682
# 2                   USA        NAM                     99.0      2.077
# 3             Indonésie        ASI                     88.8      2.132
# 4                Brésil        LAT                     90.2      1.827
# 5              Pakistan        ASI                     40.0      3.872
# 6            Bangladesh        ASI                     49.8      2.288
# 7               Nigéria         AF                     48.8      5.173
# 8  Fédération de Russie        EUR                     99.4      1.393
# 9                 Japan        ASI                     99.0      1.262
#
#        poblacion
# 0  1,324,655,000
# 1  1,139,964,932
# 2    304,060,000
# 3    227,345,082
# 4    191,971,506
# 5    166,111,487
# 6    160,000,128
# 7    151,212,254
# 8    141,950,000
# 9    127,704,000

# %%
df.tail(6)
# Out:
#                                   pais  continente  alfabetizacion femenina  \
# 162                  Antigua-et-Barbuda        NaN                     99.4
# 163              Antilles néerlandaises        NaN                     96.3
# 164                       Iles Caïmanes        NaN                     99.0
# 165                          Seychelles        NaN                     92.3
# 166  Territoires autonomes palestiniens        NaN                     90.9
# 167                               WORLD      WORLD                     77.0
#
#     fertilidad poblacion
# 162    missing       NaN
# 163    missing       NaN
# 164    missing       NaN
# 165    missing       NaN
# 166    missing       NaN
# 167        NaN       NaN

# %%
df.shape
# Out:
# (168, 5)

# %%
df.columns
# Out:
# Index(['pais ', 'continente', 'alfabetizacion femenina', 'fertilidad',
#        'poblacion'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 5 columns):
# pais                       168 non-null object
# continente                 163 non-null object
# alfabetizacion femenina    168 non-null float64
# fertilidad                 167 non-null object
# poblacion                  162 non-null object
# dtypes: float64(1), object(4)
# memory usage: 4.0+ KB

# %%
df["fertilidad"]=pd.to_numeric(df["fertilidad"],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 5 columns):
# pais                       168 non-null object
# continente                 163 non-null object
# alfabetizacion femenina    168 non-null float64
# fertilidad                 162 non-null float64
# poblacion                  162 non-null object
# dtypes: float64(2), object(3)
# memory usage: 4.6+ KB

# %%
df.continente.value_counts(dropna=False)
# Out:
# AF       49
# ASI      47
# EUR      36
# LAT      24
# NaN       5
# OCE       4
# NAM       2
# WORLD     1
# Name: continente, dtype: int64

# %%
df['pais '].value_counts(dropna=False).head()
# Out:
# Honduras     1
# WORLD        1
# Nicaragua    1
# Lettonie     1
# Angola       1
# Name: pais , dtype: int64

# %%
df.rename(columns={'pais ':'pais'},inplace=True)

# %%
df['pais'].value_counts(dropna=False).head()
# Out:
# Honduras     1
# WORLD        1
# Nicaragua    1
# Lettonie     1
# Angola       1
# Name: pais, dtype: int64

# %%
df.describe()
# Out:
#        alfabetizacion femenina  fertilidad
# count               168.000000  162.000000
# mean                 80.549405    2.878673
# std                  22.797066    1.427597
# min                  12.600000    0.966000
# 25%                  67.550000    1.823250
# 50%                  90.300000    2.367500
# 75%                  98.500000    3.880250
# max                 100.000000    7.069000

# %%
df2=pd.read_csv('tasa_natalidad_nuevo.csv',sep=',')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 5 columns):
# pais                       169 non-null object
# continente                 164 non-null object
# alfabetizacion femenina    169 non-null float64
# fertilidad                 168 non-null object
# poblacion                  163 non-null float64
# dtypes: float64(2), object(3)
# memory usage: 4.7+ KB

# %%
import matplotlib.pyplot as plt

# %%
df2.poblacion.plot('hist')

# %%
df2[df2.poblacion>1000000000]
# Out:
#           pais continente  alfabetizacion femenina fertilidad     poblacion
# 0        Chine        ASI                     90.5      1.769  1.324655e+09
# 1         Inde        ASI                     50.8      2.682  1.139965e+09
# 162  Australia        OCE                     96.0       1.93  2.313000e+09
